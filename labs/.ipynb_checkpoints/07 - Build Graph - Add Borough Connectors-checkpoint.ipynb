# %% [markdown]
# ### Import

# %%
import os
import sys
import pandas as pd
import numpy as np
import shapefile
import re
import pickle
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon as polygon
from matplotlib.collections import PatchCollection as patchCollection
from tqdm import tqdm
from collections import Counter
from scipy.spatial.distance import cdist
from scipy.spatial.distance import pdist

# %% [markdown]
# ### Borough Codes

# %%
B = {}
B['manhattan'] = 1
B['thebronx'] = 2
B['brooklyn'] = 3
B['queens'] = 4
B['statenisland'] = 5

# %% [markdown]
# ### Load Graphs

# %%
A = []
A.append({})
A.append(pickle.load(open("../data/graphs/nyc_manhattan.p","rb")))
A.append(pickle.load(open("../data/graphs/nyc_thebronx.p","rb")))
A.append(pickle.load(open("../data/graphs/nyc_brooklyn.p","rb")))
A.append(pickle.load(open("../data/graphs/nyc_queens.p","rb")))
A.append(pickle.load(open("../data/graphs/nyc_statenisland.p","rb")))

# %% [markdown]
# ### Extract Info Helper Function

# %%
def extractInfo(borough,A,B):
    
    #Extract
    index = B[borough]
    X = A[index]
    G = X['G']
    O = X['O']
    N = X['N']
    streets = X['streets']
    coordsdf = X['coordsdf']
    edges = X['edges']
    nodes = X['nodes']
    nodenames = X['nodenames']

    #Restrict
    streets = streets[['borocode', 'id', 'orig_id',\
                       'l_high_hn', 'l_low_hn', 'l_zip',\
                       'r_high_hn', 'r_low_hn', 'r_zip',\
                       'shape_leng', 'st_label', 'trafdir',\
                       'slng', 'slat', 'elng', 'elat',\
                       'sendpoint','eendpoint','endpoint']]

    #Return
    return G,O,N,streets,coordsdf,edges,nodes,nodenames

# %% [markdown]
# ### Add Borough to Node Names Helper Function

# %%
def addBoroughNameToNodes(nodes,nodenames,edges,borough):
    
    #Add Borough to nodes
    newnodes = []
    newnames = []
    newedgenames = []
    for n,node in enumerate(nodes):
        newnode = {}
        for item in node:
            newitem = str(item) + '-' + borough
            newnode[newitem] = node[item]
        newname = nodenames[n] + ' | ' + borough.upper()
        newnames.append(newname)
        newnodes.append(newnode)
    
    #Add Borough Name
    for i in range(len(edges)):
        node1,node2,length = edges[i]
        node1 = node1 + ' | ' + borough.upper()
        node2 = node2 + ' | ' + borough.upper() 
        edges[i] = (node1,node2,length)

    #Return
    return newnodes,newnames,newedgenames

# %% [markdown]
# ### Get Borough Data

# %%
Bdata = {}
boroughs = list(B.keys())
for borough in boroughs:
    G,O,N,streets,coordsdf,edges,nodes,nodena = extractInfo(borough,A,B)
    Bdata[borough] = (G,O,N,streets,coordsdf,edges,nodes,nodena)

# %% [markdown]
# ### Find indices of streets that are not fully connected

# %%
for borough in boroughs:
    (G,O,N,streets,coordsdf,edges,nodes,nodena) = Bdata[borough]
    s1 = streets[streets['sendpoint'] > 0.0]
    e1 = streets[streets['eendpoint'] > 0.0]
    cstreets = pd.concat((s1,e1),axis=0)
    slnglat = cstreets[['slng','slat']].values
    elnglat = cstreets[['elng','elat']].values
    Bdata[borough] = (G,O,N,streets,coordsdf,edges,nodes,nodena,cstreets,slnglat,elnglat)

# %% [markdown]
# ### Connection Node Creator

# %%
def connectionNodeCreator(pos1,pos2,type1,type2,streets1,streets2,borough1,borough2):

    #Create New Connection Nodes
    nodenames = []
    nodes = []
    for i in range(len(pos1)):
        i1 = pos1[i]
        i2 = pos2[i]
        index1 = streets1.iloc[i1].id
        index2 = streets2.iloc[i2].id
        name1 = streets1.iloc[i1].st_label.upper()
        name2 = streets2.iloc[i2].st_label.upper()
        lng = streets1.iloc[i1].elng
        lat = streets1.iloc[i1].elat
        nodename = name1 + ' | ' + name2 + ' | ' + str(lng) + ' | ' + str(lat) + ' | ' + borough1.upper() + ' <-> ' + borough2.upper()
        index1 = str(index1) + '-' + borough1
        index2 = str(index2) + '-' + borough2
        node = {index1:type1,index2:type2}    
        nodenames.append(nodename)
        nodes.append(node)        

    #Return
    return nodes,nodenames

# %% [markdown]
# ### Add Borough and height to Node Names

# %%
newedges = []
newnodes = []
newnodenames = []
for borough in boroughs:
    (G,O,N,streets,coordsdf,edges,nodes,nodena,cstreets,slnglat,elnglat) = Bdata[borough]
    newnodes_tmp,newnodenames_tmp, edgenames_tmp = addBoroughNameToNodes(nodes,nodena,edges,borough)
    newedges = newedges + edges
    newnodes = newnodes + newnodes_tmp
    newnodenames = newnodenames + newnodenames_tmp

# %% [markdown]
# ### Compute Distance Matrices and create Nodes

# %%
mindistance = 0.00000001
for b1,borough1 in enumerate(boroughs):
    for b2,borough2 in enumerate(boroughs[b1+1:]):
     
        #Create Connection Nodes
        print(borough1,' <-> ',borough2)
        (G1,O1,N1,streets1,coordsdf1,edges1,nodes1,nodena1,cstreets1,s1lnglat,e1lnglat) = Bdata[borough1]
        (G2,O2,N2,streets2,coordsdf2,edges2,nodes2,nodena2,cstreets2,s2lnglat,e2lnglat) = Bdata[borough2]    
        D1 = cdist(s1lnglat,s2lnglat)
        D2 = cdist(e1lnglat,e2lnglat)
        D3 = cdist(s1lnglat,e2lnglat)
        D4 = cdist(e1lnglat,s2lnglat)
        pos1,pos2 = np.where(D1 < mindistance)
        nodes1,nodenames1 = connectionNodeCreator(pos1,pos2,'s','s',cstreets1,cstreets2,borough1,borough2)
        pos1,pos2 = np.where(D2 < mindistance)
        nodes2,nodenames2 = connectionNodeCreator(pos1,pos2,'e','e',cstreets1,cstreets2,borough1,borough2)
        pos1,pos2 = np.where(D3 < mindistance)
        nodes3,nodenames3 = connectionNodeCreator(pos1,pos2,'s','e',cstreets1,cstreets2,borough1,borough2)
        pos1,pos2 = np.where(D4 < mindistance)
        nodes4,nodenames4 = connectionNodeCreator(pos1,pos2,'e','s',cstreets1,cstreets2,borough1,borough2)
        connodes = nodes1 + nodes2 + nodes3 + nodes4
        connodenames = nodenames1 + nodenames2 + nodenames3 + nodenames4

        #Add Nodes to existing bag of nodes
        for n,node1 in enumerate(connodes):

            #Create element in node to look for
            nodename1 = connodenames[n]
            for orig_edge in node1:
                elements = orig_edge.split('-')
                edge = int(elements[0])
                borough = elements[1]
                if borough == borough1:
                    street = streets1.iloc[edge]
                    length = street.shape_leng
                if borough == borough2:
                    street = streets2.iloc[edge]
                    length = street.shape_leng
                edgetype = node1[orig_edge]
                for o,node2 in enumerate(newnodes):
                    nodename2 = newnodenames[o]
                    if (edgetype == 's'):
                        othertype = 'e'
                    else:
                        othertype = 's'
                    if (orig_edge in node2):
                        if (node2[orig_edge] == othertype):
                            newedges.append((nodename1,nodename2,length))
# Out:
# manhattan  <->  thebronx
# manhattan  <->  brooklyn
# manhattan  <->  queens
# manhattan  <->  statenisland
# thebronx  <->  brooklyn
# thebronx  <->  queens
# thebronx  <->  statenisland
# brooklyn  <->  queens
# brooklyn  <->  statenisland
# queens  <->  statenisland

# %% [markdown]
# ### Dictionaries

# %%
N = {}
O = {}
Nlist = []
for edge in newedges:
    node1 = edge[0]
    node2 = edge[1]
    Nlist.append(node1)
    Nlist.append(node2)
Nlist = np.unique(Nlist)
for i,item in enumerate(Nlist):
    N[i] = item
    O[item] = i

# %% [markdown]
# ### Create Graph from edges

# %%
G = nx.Graph()
edgedatabase = []
for e,edge in enumerate(newedges):
    node1 = edge[0]
    node2 = edge[1]
    index1 = O[node1]
    index2 = O[node2]
    length = float(edge[2])
    if (length < 0):
        print(node1,node2,length)
    elements1 = node1.split(' | ')
    elements2 = node2.split(' | ')
    lat1 = float(elements1[-2])
    lng1 = float(elements1[-3])
    lat2 = float(elements2[-2])
    lng2 = float(elements2[-3])
    nodename1 = str(index1) + ' | ' + ' | '.join(elements1[:])
    nodename2 = str(index2) + ' | ' + ' | '.join(elements2[:])
    edgedatabase.append((index1,nodename1,lat1,lng2,index2,nodename2,lat2,lng2))
    G.add_edge(index1,index2, weight=length)
edgedatabase = pd.DataFrame(edgedatabase)
edgedatabase.columns = ['index1','nodename1','lat1','lng1','index2','nodename2','lat2','lng2']

# %%
for n in range(120342,130342):
    name = names[n]
    elements = name.split(' | ')
    if 'THEBRONX' in elements[-1]:
        print(n,name)
# Out:
# 120342 250011 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87861544017795 | 40.86191530153914 | THEBRONX
# 120343 250011 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87861544017795 | 40.86191530153914 | THEBRONX
# 120344 250011 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87861544017795 | 40.86191530153914 | THEBRONX
# 120345 250009 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786122906838 | 40.861905665471 | THEBRONX
# 120346 250009 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786122906838 | 40.861905665471 | THEBRONX
# 120347 250008 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860961001435 | 40.86189594747457 | THEBRONX
# 120348 250008 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860961001435 | 40.86189594747457 | THEBRONX
# 120349 250002 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786074016745 | 40.861886161457974 | THEBRONX
# 120350 250002 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786074016745 | 40.861886161457974 | THEBRONX
# 120351 249998 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860566917195 | 40.86187631982168 | THEBRONX
# 120352 249998 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860566917195 | 40.86187631982168 | THEBRONX
# 120353 249991 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860441468642 | 40.861866437142524 | THEBRONX
# 120354 249991 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860441468642 | 40.861866437142524 | THEBRONX
# 120355 249988 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860363951931 | 40.86185652565106 | THEBRONX
# 120356 249988 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860363951931 | 40.86185652565106 | THEBRONX
# 120357 249985 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860334518933 | 40.861846599420886 | THEBRONX
# 120358 249985 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860334518933 | 40.861846599420886 | THEBRONX
# 120359 249987 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860353255412 | 40.86183667202225 | THEBRONX
# 120360 249987 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860353255412 | 40.86183667202225 | THEBRONX
# 120361 249990 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860420004561 | 40.86182675618532 | THEBRONX
# 120362 249990 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860420004561 | 40.86182675618532 | THEBRONX
# 120363 249999 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860634362991 | 40.86181181620364 | THEBRONX
# 120364 249999 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860634362991 | 40.86181181620364 | THEBRONX
# 120365 250003 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860791909888 | 40.861796835083545 | THEBRONX
# 120366 250003 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860791909888 | 40.861796835083545 | THEBRONX
# 120367 250005 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860892466473 | 40.86178182538742 | THEBRONX
# 120368 250005 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860892466473 | 40.86178182538742 | THEBRONX
# 120369 250007 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860935986241 | 40.86176680034911 | THEBRONX
# 120370 250007 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860935986241 | 40.86176680034911 | THEBRONX
# 120371 250006 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786092240086 | 40.86175177186207 | THEBRONX
# 120372 250006 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786092240086 | 40.86175177186207 | THEBRONX
# 120373 250004 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860851663821 | 40.86173675316013 | THEBRONX
# 120374 250004 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860851663821 | 40.86173675316013 | THEBRONX
# 120375 250000 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860723971737 | 40.86172175530189 | THEBRONX
# 120376 250000 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860723971737 | 40.86172175530189 | THEBRONX
# 120377 249997 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860539300073 | 40.861706792024 | THEBRONX
# 120378 249997 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860539300073 | 40.861706792024 | THEBRONX
# 120379 249984 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860297911358 | 40.861691875893406 | THEBRONX
# 120380 249984 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860297911358 | 40.861691875893406 | THEBRONX
# 120381 249980 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859999913972 | 40.86167701780025 | THEBRONX
# 120382 249980 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859999913972 | 40.86167701780025 | THEBRONX
# 120383 249975 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859645636273 | 40.86166223232246 | THEBRONX
# 120384 249975 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859645636273 | 40.86166223232246 | THEBRONX
# 120385 249970 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859235319092 | 40.86164753001648 | THEBRONX
# 120386 249970 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859235319092 | 40.86164753001648 | THEBRONX
# 120387 249967 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87858769313219 | 40.86163292345018 | THEBRONX
# 120388 249967 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87858769313219 | 40.86163292345018 | THEBRONX
# 120389 249962 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87858247969412 | 40.86161842535897 | THEBRONX
# 120390 249962 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87858247969412 | 40.86161842535897 | THEBRONX
# 120391 249960 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87857671793161 | 40.86160404697215 | THEBRONX
# 120392 249960 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87857671793161 | 40.86160404697215 | THEBRONX
# 120393 249958 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87857041311688 | 40.86158980136198 | THEBRONX
# 120394 249958 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87857041311688 | 40.86158980136198 | THEBRONX
# 120395 249953 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87856356920302 | 40.861575698919005 | THEBRONX
# 120396 249953 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87856356920302 | 40.861575698919005 | THEBRONX
# 120397 249951 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87855619146161 | 40.86156175305051 | THEBRONX
# 120398 249951 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87855619146161 | 40.86156175305051 | THEBRONX
# 120399 249946 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87854828847979 | 40.861547973984386 | THEBRONX
# 120400 249946 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87854828847979 | 40.861547973984386 | THEBRONX
# 120401 249941 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87853986442792 | 40.861534373954086 | THEBRONX
# 120402 249941 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87853986442792 | 40.861534373954086 | THEBRONX
# 120403 249939 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87853092744972 | 40.86152096435966 | THEBRONX
# 120404 249939 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87853092744972 | 40.86152096435966 | THEBRONX
# 120405 249933 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8785214848077 | 40.86150775576261 | THEBRONX
# 120406 249933 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8785214848077 | 40.86150775576261 | THEBRONX
# 120407 249926 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87851154442609 | 40.86149475889263 | THEBRONX
# 120408 249926 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87851154442609 | 40.86149475889263 | THEBRONX
# 120409 249917 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87850111400626 | 40.86148198565189 | THEBRONX
# 120410 249917 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87850111400626 | 40.86148198565189 | THEBRONX
# 120411 249909 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87849339904342 | 40.861472554343635 | THEBRONX
# 120412 249909 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87849339904342 | 40.861472554343635 | THEBRONX
# 120413 249903 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87848617610794 | 40.86146290091462 | THEBRONX
# 120414 249903 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87848617610794 | 40.86146290091462 | THEBRONX
# 120415 249897 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784794568671 | 40.861453040286776 | THEBRONX
# 120416 249897 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784794568671 | 40.861453040286776 | THEBRONX
# 120417 249893 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87847325122357 | 40.86144298704517 | THEBRONX
# 120418 249893 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87847325122357 | 40.86144298704517 | THEBRONX
# 120419 249887 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87846756863532 | 40.861432757617095 | THEBRONX
# 120420 249887 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87846756863532 | 40.861432757617095 | THEBRONX
# 120421 249883 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87846241790137 | 40.86142236675397 | THEBRONX
# 120422 249883 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87846241790137 | 40.86142236675397 | THEBRONX
# 120423 249880 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87845780693476 | 40.86141183104899 | THEBRONX
# 120424 249880 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87845780693476 | 40.86141183104899 | THEBRONX
# 120425 249877 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784537425477 | 40.861401165754 | THEBRONX
# 120426 249877 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784537425477 | 40.861401165754 | THEBRONX
# 120427 249874 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87845023088582 | 40.86139038863303 | THEBRONX
# 120428 249874 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87845023088582 | 40.86139038863303 | THEBRONX
# 120429 249871 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844727832025 | 40.861379514769936 | THEBRONX
# 120430 249871 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844727832025 | 40.861379514769936 | THEBRONX
# 120431 249867 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844488856913 | 40.86136856209364 | THEBRONX
# 120432 249867 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844488856913 | 40.86136856209364 | THEBRONX
# 120433 249865 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784430649126 | 40.861357546689895 | THEBRONX
# 120434 249865 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784430649126 | 40.861357546689895 | THEBRONX
# 120435 249864 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844181107086 | 40.86134648531494 | THEBRONX
# 120436 249864 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844181107086 | 40.86134648531494 | THEBRONX
# 120437 249861 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844112855731 | 40.86133539489028 | THEBRONX
# 120438 249861 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844112855731 | 40.86133539489028 | THEBRONX
# 120439 249859 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87843982428429 | 40.86132234847885 | THEBRONX
# 120440 249859 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87843982428429 | 40.86132234847885 | THEBRONX
# 120441 249857 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87843798772593 | 40.86130933886429 | THEBRONX
# 120442 249857 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87843798772593 | 40.86130933886429 | THEBRONX
# 120443 249855 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87843561885926 | 40.861296378778285 | THEBRONX
# 120444 249855 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87843561885926 | 40.861296378778285 | THEBRONX
# 120445 249851 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87843272119147 | 40.86128348112378 | THEBRONX
# 120446 249851 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87843272119147 | 40.86128348112378 | THEBRONX
# 120447 249843 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784292973496 | 40.86127065746262 | THEBRONX
# 120448 249843 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784292973496 | 40.86127065746262 | THEBRONX
# 120449 249840 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87842534951592 | 40.861257921198906 | THEBRONX
# 120450 249840 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87842534951592 | 40.861257921198906 | THEBRONX
# 120451 249837 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87842088340605 | 40.8612452842328 | THEBRONX
# 120452 249837 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87842088340605 | 40.8612452842328 | THEBRONX
# 120453 249833 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841590208792 | 40.86123275829408 | THEBRONX
# 120454 249833 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841590208792 | 40.86123275829408 | THEBRONX
# 120455 249828 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841041083394 | 40.861220356287504 | THEBRONX
# 120456 249828 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841041083394 | 40.861220356287504 | THEBRONX
# 120457 249821 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840441469886 | 40.861208089442414 | THEBRONX
# 120458 249821 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840441469886 | 40.861208089442414 | THEBRONX
# 120459 249815 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87839791939724 | 40.86119597016148 | THEBRONX
# 120460 249815 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87839791939724 | 40.86119597016148 | THEBRONX
# 120461 249813 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87839422197551 | 40.861187600487156 | THEBRONX
# 120462 249813 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87839422197551 | 40.861187600487156 | THEBRONX
# 120463 249811 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87839105677973 | 40.86117910606626 | THEBRONX
# 120464 249811 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87839105677973 | 40.86117910606626 | THEBRONX
# 120465 249810 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87838843039377 | 40.86117050633846 | THEBRONX
# 120466 249810 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87838843039377 | 40.86117050633846 | THEBRONX
# 120467 249809 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87838634962061 | 40.861161821581284 | THEBRONX
# 120468 249809 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87838634962061 | 40.861161821581284 | THEBRONX
# 120469 249808 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87838481751525 | 40.8611530703931 | THEBRONX
# 120470 249808 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87838481751525 | 40.8611530703931 | THEBRONX
# 120471 249806 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87837275110545 | 40.86113434096803 | THEBRONX
# 120472 249806 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87837275110545 | 40.86113434096803 | THEBRONX
# 120473 249803 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87836024529666 | 40.86111577809909 | THEBRONX
# 120474 249803 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87836024529666 | 40.86111577809909 | THEBRONX
# 120475 249801 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8783473040493 | 40.86109738815621 | THEBRONX
# 120476 249801 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8783473040493 | 40.86109738815621 | THEBRONX
# 120477 249798 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87833393220787 | 40.86107917667263 | THEBRONX
# 120478 249798 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87833393220787 | 40.86107917667263 | THEBRONX
# 120479 249796 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87832013351269 | 40.86106114968297 | THEBRONX
# 120480 249796 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87832013351269 | 40.86106114968297 | THEBRONX
# 120481 249793 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87830591214629 | 40.861043312719765 | THEBRONX
# 120482 249793 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87830591214629 | 40.861043312719765 | THEBRONX
# 120483 249790 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87829127317256 | 40.86102567198653 | THEBRONX
# 120484 249790 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87829127317256 | 40.86102567198653 | THEBRONX
# 120485 249788 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87827622055399 | 40.86100823268057 | THEBRONX
# 120486 249788 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87827622055399 | 40.86100823268057 | THEBRONX
# 120487 249785 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87826076023669 | 40.860991001173836 | THEBRONX
# 120488 249785 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87826076023669 | 40.860991001173836 | THEBRONX
# 120489 249783 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87824489618527 | 40.860973981490936 | THEBRONX
# 120490 249783 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87824489618527 | 40.860973981490936 | THEBRONX
# 120491 249778 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87822863324163 | 40.860957180505245 | THEBRONX
# 120492 249778 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87822863324163 | 40.860957180505245 | THEBRONX
# 120493 249774 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87821197801784 | 40.86094060241167 | THEBRONX
# 120494 249774 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87821197801784 | 40.86094060241167 | THEBRONX
# 120495 249771 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87820229950542 | 40.86093108357343 | THEBRONX
# 120496 249771 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87820229950542 | 40.86093108357343 | THEBRONX
# 120497 249768 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87819308153357 | 40.860921304889374 | THEBRONX
# 120498 249768 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87819308153357 | 40.860921304889374 | THEBRONX
# 120499 249765 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87818433511062 | 40.86091127960555 | THEBRONX
# 120500 249765 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87818433511062 | 40.86091127960555 | THEBRONX
# 120501 249762 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8781760723487 | 40.86090102063419 | THEBRONX
# 120502 249762 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8781760723487 | 40.86090102063419 | THEBRONX
# 120503 249760 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87816830359382 | 40.86089054138816 | THEBRONX
# 120504 249760 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87816830359382 | 40.86089054138816 | THEBRONX
# 120505 249757 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87816103941198 | 40.860879855615615 | THEBRONX
# 120506 249757 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87816103941198 | 40.860879855615615 | THEBRONX
# 120507 249754 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87815428882426 | 40.86086897723063 | THEBRONX
# 120508 249754 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87815428882426 | 40.86086897723063 | THEBRONX
# 120509 249751 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87814806129218 | 40.8608579206503 | THEBRONX
# 120510 249751 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87814806129218 | 40.8608579206503 | THEBRONX
# 120511 249749 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87814236407061 | 40.86084670028934 | THEBRONX
# 120512 249749 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87814236407061 | 40.86084670028934 | THEBRONX
# 120513 249746 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87813720662102 | 40.860835330564846 | THEBRONX
# 120514 249746 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87813720662102 | 40.860835330564846 | THEBRONX
# 120515 249743 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87813259288633 | 40.8608238270607 | THEBRONX
# 120516 249743 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87813259288633 | 40.8608238270607 | THEBRONX
# 120517 249741 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812853056307 | 40.86081220402459 | THEBRONX
# 120518 249741 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812853056307 | 40.86081220402459 | THEBRONX
# 120519 249738 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812502513869 | 40.86080047704206 | THEBRONX
# 120520 249738 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812502513869 | 40.86080047704206 | THEBRONX
# 120521 249736 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812208077648 | 40.86078866186472 | THEBRONX
# 120522 249736 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812208077648 | 40.86078866186472 | THEBRONX
# 120523 249734 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811970142083 | 40.86077677323882 | THEBRONX
# 120524 249734 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811970142083 | 40.86077677323882 | THEBRONX
# 120525 249731 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811788969046 | 40.86076482691436 | THEBRONX
# 120526 249731 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811788969046 | 40.86076482691436 | THEBRONX
# 120527 249728 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811664864502 | 40.86075283880932 | THEBRONX
# 120528 249728 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811664864502 | 40.86075283880932 | THEBRONX
# 120529 249726 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8781159793586 | 40.86074082467204 | THEBRONX
# 120530 249726 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8781159793586 | 40.86074082467204 | THEBRONX
# 120531 249725 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811588356878 | 40.86072879941394 | THEBRONX
# 120532 249725 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811588356878 | 40.86072879941394 | THEBRONX
# 120533 249727 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811636036194 | 40.86071677978638 | THEBRONX
# 120534 249727 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811636036194 | 40.86071677978638 | THEBRONX
# 120535 249729 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811683647155 | 40.86070429025522 | THEBRONX
# 120536 249729 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811683647155 | 40.86070429025522 | THEBRONX
# 120537 249730 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811784851246 | 40.86069181888013 | THEBRONX
# 120538 249730 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811784851246 | 40.86069181888013 | THEBRONX
# 120539 249733 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811939557778 | 40.86067937872696 | THEBRONX
# 120540 249733 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87811939557778 | 40.86067937872696 | THEBRONX
# 120541 249735 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812147455175 | 40.860666984199376 | THEBRONX
# 120542 249735 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812147455175 | 40.860666984199376 | THEBRONX
# 120543 249737 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812408497062 | 40.86065464735854 | THEBRONX
# 120544 249737 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812408497062 | 40.86065464735854 | THEBRONX
# 120545 249740 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812722372104 | 40.860642381267944 | THEBRONX
# 120546 249740 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87812722372104 | 40.860642381267944 | THEBRONX
# 120547 249742 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87813088570226 | 40.86063019982662 | THEBRONX
# 120548 249742 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87813088570226 | 40.86063019982662 | THEBRONX
# 120549 249745 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87813506956832 | 40.86061811492722 | THEBRONX
# 120550 249745 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87813506956832 | 40.86061811492722 | THEBRONX
# 120551 249747 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87813976889484 | 40.86060614029984 | THEBRONX
# 120552 249747 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87813976889484 | 40.86060614029984 | THEBRONX
# 120553 249750 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87814498057007 | 40.86059428817029 | THEBRONX
# 120554 249750 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87814498057007 | 40.86059428817029 | THEBRONX
# 120555 249753 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87815069662727 | 40.86058257109438 | THEBRONX
# 120556 249753 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87815069662727 | 40.86058257109438 | THEBRONX
# 120557 249755 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87815691351277 | 40.86057100163251 | THEBRONX
# 120558 249755 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87815691351277 | 40.86057100163251 | THEBRONX
# 120559 249758 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87816362303923 | 40.8605595923402 | THEBRONX
# 120560 249758 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87816362303923 | 40.8605595923402 | THEBRONX
# 120561 249761 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87817081834596 | 40.860548354266655 | THEBRONX
# 120562 249761 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87817081834596 | 40.860548354266655 | THEBRONX
# 120563 249764 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87817849190613 | 40.86053730080571 | THEBRONX
# 120564 249764 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87817849190613 | 40.86053730080571 | THEBRONX
# 120565 249767 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87818663641777 | 40.86052644300611 | THEBRONX
# 120566 249767 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87818663641777 | 40.86052644300611 | THEBRONX
# 120567 249769 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87819524193057 | 40.86051579224882 | THEBRONX
# 120568 249769 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87819524193057 | 40.86051579224882 | THEBRONX
# 120569 249772 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87820429981808 | 40.86050535991621 | THEBRONX
# 120570 249772 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87820429981808 | 40.86050535991621 | THEBRONX
# 120571 249775 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87821380035163 | 40.860495156886955 | THEBRONX
# 120572 249775 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87821380035163 | 40.860495156886955 | THEBRONX
# 120573 249777 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87822373424257 | 40.86048519471021 | THEBRONX
# 120574 249777 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87822373424257 | 40.86048519471021 | THEBRONX
# 120575 249780 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87823408911684 | 40.86047548292164 | THEBRONX
# 120576 249780 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87823408911684 | 40.86047548292164 | THEBRONX
# 120577 249782 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87824485634847 | 40.86046603273613 | THEBRONX
# 120578 249782 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87824485634847 | 40.86046603273613 | THEBRONX
# 120579 249787 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87826882581723 | 40.86044971663271 | THEBRONX
# 120580 249787 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87826882581723 | 40.86044971663271 | THEBRONX
# 120581 249791 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87829312595134 | 40.86043368516013 | THEBRONX
# 120582 249791 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87829312595134 | 40.86043368516013 | THEBRONX
# 120583 249795 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8783177514479 | 40.86041794233312 | THEBRONX
# 120584 249795 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8783177514479 | 40.86041794233312 | THEBRONX
# 120585 249800 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87834269612324 | 40.86040249116041 | THEBRONX
# 120586 249800 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87834269612324 | 40.86040249116041 | THEBRONX
# 120587 249805 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87836795401041 | 40.86038733682871 | THEBRONX
# 120588 249805 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87836795401041 | 40.86038733682871 | THEBRONX
# 120589 249812 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87839351870575 | 40.86037248201145 | THEBRONX
# 120590 249812 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87839351870575 | 40.86037248201145 | THEBRONX
# 120591 249836 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841938490672 | 40.860357930555836 | THEBRONX
# 120592 249836 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841938490672 | 40.860357930555836 | THEBRONX
# 120593 249869 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844554554565 | 40.86034368630733 | THEBRONX
# 120594 249869 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844554554565 | 40.86034368630733 | THEBRONX
# 120595 249890 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87847199421917 | 40.86032975177177 | THEBRONX
# 120596 249890 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87847199421917 | 40.86032975177177 | THEBRONX
# 120597 249896 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87847903822377 | 40.86032640621215 | THEBRONX
# 120598 249896 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87847903822377 | 40.86032640621215 | THEBRONX
# 120599 249902 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87848582702662 | 40.86032276855775 | THEBRONX
# 120600 249902 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87848582702662 | 40.86032276855775 | THEBRONX
# 120601 249908 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87849233854237 | 40.86031884984186 | THEBRONX
# 120602 249908 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87849233854237 | 40.86031884984186 | THEBRONX
# 120603 249914 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87849855333201 | 40.86031466193821 | THEBRONX
# 120604 249914 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87849855333201 | 40.86031466193821 | THEBRONX
# 120605 249919 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8785044512915 | 40.8603102183951 | THEBRONX
# 120606 249919 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8785044512915 | 40.8603102183951 | THEBRONX
# 120607 249924 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87851001496405 | 40.8603055330986 | THEBRONX
# 120608 249924 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87851001496405 | 40.8603055330986 | THEBRONX
# 120609 249928 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87851522601116 | 40.86030061943133 | THEBRONX
# 120610 249928 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87851522601116 | 40.86030061943133 | THEBRONX
# 120611 249932 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87852007028154 | 40.860295493628186 | THEBRONX
# 120612 249932 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87852007028154 | 40.860295493628186 | THEBRONX
# 120613 249968 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859081878089 | 40.86021908818022 | THEBRONX
# 120614 249968 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859081878089 | 40.86021908818022 | THEBRONX
# 120615 249972 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859428291951 | 40.86021465966131 | THEBRONX
# 120616 249972 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859428291951 | 40.86021465966131 | THEBRONX
# 120617 249976 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859729616642 | 40.86021004505204 | THEBRONX
# 120618 249976 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859729616642 | 40.86021004505204 | THEBRONX
# 120619 249979 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859984192428 | 40.860205270971164 | THEBRONX
# 120620 249979 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859984192428 | 40.860205270971164 | THEBRONX
# 120621 249982 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860190580169 | 40.86020036437485 | THEBRONX
# 120622 249982 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860190580169 | 40.86020036437485 | THEBRONX
# 120623 249986 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860347671511 | 40.86019535322783 | THEBRONX
# 120624 249986 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860347671511 | 40.86019535322783 | THEBRONX
# 120625 249992 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860454379964 | 40.860190266667786 | THEBRONX
# 120626 249992 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860454379964 | 40.860190266667786 | THEBRONX
# 120627 249995 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860510258942 | 40.86018513367151 | THEBRONX
# 120628 249995 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860510258942 | 40.86018513367151 | THEBRONX
# 120629 249996 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860514972256 | 40.860179982881995 | THEBRONX
# 120630 249996 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860514972256 | 40.860179982881995 | THEBRONX
# 120631 249994 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786046840409 | 40.86017484445221 | THEBRONX
# 120632 249994 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786046840409 | 40.86017484445221 | THEBRONX
# 120633 249989 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786037085804 | 40.86016974753439 | THEBRONX
# 120634 249989 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786037085804 | 40.86016974753439 | THEBRONX
# 120635 249983 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860222968841 | 40.86016472044663 | THEBRONX
# 120636 249983 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87860222968841 | 40.86016472044663 | THEBRONX
# 120637 249981 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786002548133 | 40.860159792680896 | THEBRONX
# 120638 249981 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8786002548133 | 40.860159792680896 | THEBRONX
# 120639 249978 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8785977958189 | 40.860154992393525 | THEBRONX
# 120640 249978 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8785977958189 | 40.860154992393525 | THEBRONX
# 120641 249974 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859486589451 | 40.860150346904646 | THEBRONX
# 120642 249974 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859486589451 | 40.860150346904646 | THEBRONX
# 120643 249969 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859148308608 | 40.86014588219937 | THEBRONX
# 120644 249969 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87859148308608 | 40.86014588219937 | THEBRONX
# 120645 249966 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87858766521863 | 40.86014162443005 | THEBRONX
# 120646 249966 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87858766521863 | 40.86014162443005 | THEBRONX
# 120647 249964 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87858343563802 | 40.86013759724195 | THEBRONX
# 120648 249964 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87858343563802 | 40.86013759724195 | THEBRONX
# 120649 249957 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87856936588649 | 40.860127065321564 | THEBRONX
# 120650 249957 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87856936588649 | 40.860127065321564 | THEBRONX
# 120651 249950 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87855570468096 | 40.86011622742936 | THEBRONX
# 120652 249950 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87855570468096 | 40.86011622742936 | THEBRONX
# 120653 249945 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87854246391906 | 40.86010509312679 | THEBRONX
# 120654 249945 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87854246391906 | 40.86010509312679 | THEBRONX
# 120655 249938 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87852965461767 | 40.86009367096931 | THEBRONX
# 120656 249938 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87852965461767 | 40.86009367096931 | THEBRONX
# 120657 249930 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87851728756807 | 40.86008197219249 | THEBRONX
# 120658 249930 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87851728756807 | 40.86008197219249 | THEBRONX
# 120659 249920 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87850537312512 | 40.86007000535105 | THEBRONX
# 120660 249920 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87850537312512 | 40.86007000535105 | THEBRONX
# 120661 249910 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87849392097803 | 40.86005778100931 | THEBRONX
# 120662 249910 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87849392097803 | 40.86005778100931 | THEBRONX
# 120663 249901 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87848294081631 | 40.86004530956406 | THEBRONX
# 120664 249901 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87848294081631 | 40.86004530956406 | THEBRONX
# 120665 249892 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87847244255099 | 40.860032600909726 | THEBRONX
# 120666 249892 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87847244255099 | 40.860032600909726 | THEBRONX
# 120667 249884 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87846243476581 | 40.86001966678214 | THEBRONX
# 120668 249884 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87846243476581 | 40.86001966678214 | THEBRONX
# 120669 249875 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784529258269 | 40.860006517241615 | THEBRONX
# 120670 249875 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784529258269 | 40.860006517241615 | THEBRONX
# 120671 249866 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844392387761 | 40.85999316352092 | THEBRONX
# 120672 249866 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844392387761 | 40.85999316352092 | THEBRONX
# 120673 249854 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784354357367 | 40.85997961718648 | THEBRONX
# 120674 249854 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784354357367 | 40.85997961718648 | THEBRONX
# 120675 249841 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87842746998936 | 40.859965889136475 | THEBRONX
# 120676 249841 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87842746998936 | 40.859965889136475 | THEBRONX
# 120677 249838 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87842278884038 | 40.859955299578324 | THEBRONX
# 120678 249838 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87842278884038 | 40.859955299578324 | THEBRONX
# 120679 249835 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841859532267 | 40.85994459293245 | THEBRONX
# 120680 249835 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841859532267 | 40.85994459293245 | THEBRONX
# 120681 249832 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784148938245 | 40.8599337826054 | THEBRONX
# 120682 249832 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784148938245 | 40.8599337826054 | THEBRONX
# 120683 249829 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841168983894 | 40.85992288116726 | THEBRONX
# 120684 249829 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841168983894 | 40.85992288116726 | THEBRONX
# 120685 249826 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840898554833 | 40.859911901687184 | THEBRONX
# 120686 249826 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840898554833 | 40.859911901687184 | THEBRONX
# 120687 249824 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840678445868 | 40.85990085740324 | THEBRONX
# 120688 249824 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840678445868 | 40.85990085740324 | THEBRONX
# 120689 249822 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840509051718 | 40.859889761553966 | THEBRONX
# 120690 249822 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840509051718 | 40.859889761553966 | THEBRONX
# 120691 249819 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840390480082 | 40.85987862837998 | THEBRONX
# 120692 249819 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840390480082 | 40.85987862837998 | THEBRONX
# 120693 249817 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840322905157 | 40.85986747044742 | THEBRONX
# 120694 249817 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840322905157 | 40.85986747044742 | THEBRONX
# 120695 249816 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840306368626 | 40.85985630099104 | THEBRONX
# 120696 249816 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840306368626 | 40.85985630099104 | THEBRONX
# 120697 249818 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784034100025 | 40.85984513425171 | THEBRONX
# 120698 249818 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784034100025 | 40.85984513425171 | THEBRONX
# 120699 249820 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840426621065 | 40.8598339834619 | THEBRONX
# 120700 249820 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840426621065 | 40.8598339834619 | THEBRONX
# 120701 249823 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840563206592 | 40.85982286168811 | THEBRONX
# 120702 249823 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840563206592 | 40.85982286168811 | THEBRONX
# 120703 249825 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840750555678 | 40.85981178283269 | THEBRONX
# 120704 249825 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87840750555678 | 40.85981178283269 | THEBRONX
# 120705 249827 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784098848942 | 40.859800759792996 | THEBRONX
# 120706 249827 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784098848942 | 40.859800759792996 | THEBRONX
# 120707 249830 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841383545249 | 40.859791318321435 | THEBRONX
# 120708 249830 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841383545249 | 40.859791318321435 | THEBRONX
# 120709 249834 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841832149336 | 40.85978201528571 | THEBRONX
# 120710 249834 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87841832149336 | 40.85978201528571 | THEBRONX
# 120711 249839 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784233343785 | 40.859772868601645 | THEBRONX
# 120712 249839 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784233343785 | 40.859772868601645 | THEBRONX
# 120713 249842 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87842886436796 | 40.859763895346276 | THEBRONX
# 120714 249842 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87842886436796 | 40.859763895346276 | THEBRONX
# 120715 249853 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87843490105986 | 40.859755112595955 | THEBRONX
# 120716 249853 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87843490105986 | 40.859755112595955 | THEBRONX
# 120717 249862 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844143405444 | 40.85974653625438 | THEBRONX
# 120718 249862 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87844143405444 | 40.85974653625438 | THEBRONX
# 120719 249873 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784484505218 | 40.85973818389786 | THEBRONX
# 120720 249873 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8784484505218 | 40.85973818389786 | THEBRONX
# 120721 249879 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87845593697654 | 40.859730069584096 | THEBRONX
# ...
# 130208 250404 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87954214908116 | 40.86147394065205 | THEBRONX
# 130209 250404 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87954214908116 | 40.86147394065205 | THEBRONX
# 130210 250407 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87954862067949 | 40.861462971954026 | THEBRONX
# 130211 250407 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87954862067949 | 40.861462971954026 | THEBRONX
# 130212 250408 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87955554962008 | 40.8614521655605 | THEBRONX
# 130213 250408 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87955554962008 | 40.8614521655605 | THEBRONX
# 130214 250437 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971562250753 | 40.86109161407034 | THEBRONX
# 130215 250437 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971562250753 | 40.86109161407034 | THEBRONX
# 130216 250435 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971359376758 | 40.86108468754819 | THEBRONX
# 130217 250435 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971359376758 | 40.86108468754819 | THEBRONX
# 130218 250431 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971208083354 | 40.86107768483811 | THEBRONX
# 130219 250431 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971208083354 | 40.86107768483811 | THEBRONX
# 130220 250429 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971108940108 | 40.861070628729195 | THEBRONX
# 130221 250429 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971108940108 | 40.861070628729195 | THEBRONX
# 130222 250427 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971062141466 | 40.861063542006654 | THEBRONX
# 130223 250427 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971062141466 | 40.861063542006654 | THEBRONX
# 130224 250428 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971067904219 | 40.861056445948215 | THEBRONX
# 130225 250428 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971067904219 | 40.861056445948215 | THEBRONX
# 130226 250430 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971126224197 | 40.86104936350451 | THEBRONX
# 130227 250430 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971126224197 | 40.86104936350451 | THEBRONX
# 130228 250433 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971236898585 | 40.861042317959175 | THEBRONX
# 130229 250433 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971236898585 | 40.861042317959175 | THEBRONX
# 130230 250436 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971399548499 | 40.86103533008113 | THEBRONX
# 130231 250436 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971399548499 | 40.86103533008113 | THEBRONX
# 130232 250438 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971613728465 | 40.861028422816396 | THEBRONX
# 130233 250438 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971613728465 | 40.861028422816396 | THEBRONX
# 130234 250439 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971878662212 | 40.86102161810237 | THEBRONX
# 130235 250439 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971878662212 | 40.86102161810237 | THEBRONX
# 130236 250442 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87972193595722 | 40.86101493687161 | THEBRONX
# 130237 250442 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87972193595722 | 40.86101493687161 | THEBRONX
# 130238 250443 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797255744387 | 40.86100840072324 | THEBRONX
# 130239 250443 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797255744387 | 40.86100840072324 | THEBRONX
# 130240 250445 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797296921001 | 40.86100203008468 | THEBRONX
# 130241 250445 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797296921001 | 40.86100203008468 | THEBRONX
# 130242 250448 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87973427434095 | 40.860995845546014 | THEBRONX
# 130243 250448 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87973427434095 | 40.860995845546014 | THEBRONX
# 130244 250450 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87973930744585 | 40.860989866358075 | THEBRONX
# 130245 250450 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87973930744585 | 40.860989866358075 | THEBRONX
# 130246 250453 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797447752728 | 40.86098411143413 | THEBRONX
# 130247 250453 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797447752728 | 40.86098411143413 | THEBRONX
# 130248 250454 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87975066057872 | 40.86097859851356 | THEBRONX
# 130249 250454 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87975066057872 | 40.86097859851356 | THEBRONX
# 130250 250457 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87975568984005 | 40.86097437747771 | THEBRONX
# 130251 250457 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87975568984005 | 40.86097437747771 | THEBRONX
# 130252 250460 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797603252507 | 40.86096990340608 | THEBRONX
# 130253 250460 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797603252507 | 40.86096990340608 | THEBRONX
# 130254 250462 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87976454536616 | 40.86096519905958 | THEBRONX
# 130255 250462 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87976454536616 | 40.86096519905958 | THEBRONX
# 130256 250465 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87976833073087 | 40.860960285525834 | THEBRONX
# 130257 250465 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87976833073087 | 40.860960285525834 | THEBRONX
# 130258 250466 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87977166232544 | 40.860955186740966 | THEBRONX
# 130259 250466 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87977166232544 | 40.860955186740966 | THEBRONX
# 130260 250468 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87977452576568 | 40.86094992580821 | THEBRONX
# 130261 250468 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87977452576568 | 40.86094992580821 | THEBRONX
# 130262 250471 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87977690622166 | 40.8609445283432 | THEBRONX
# 130263 250471 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87977690622166 | 40.8609445283432 | THEBRONX
# 130264 250473 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87977879327705 | 40.86093901963114 | THEBRONX
# 130265 250473 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87977879327705 | 40.86093901963114 | THEBRONX
# 130266 250475 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797801771763 | 40.860933425628 | THEBRONX
# 130267 250475 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797801771763 | 40.860933425628 | THEBRONX
# 130268 250477 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978105279728 | 40.860927772462084 | THEBRONX
# 130269 250477 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978105279728 | 40.860927772462084 | THEBRONX
# 130270 250479 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978141523638 | 40.860922087434595 | THEBRONX
# 130271 250479 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978141523638 | 40.860922087434595 | THEBRONX
# 130272 250478 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978126290226 | 40.86091639651001 | THEBRONX
# 130273 250478 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978126290226 | 40.86091639651001 | THEBRONX
# 130274 250476 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978059640791 | 40.8609107268277 | THEBRONX
# 130275 250476 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978059640791 | 40.8609107268277 | THEBRONX
# 130276 250482 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978720663914 | 40.86072608553019 | THEBRONX
# 130277 250482 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978720663914 | 40.86072608553019 | THEBRONX
# 130278 250481 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978541395552 | 40.860713935208594 | THEBRONX
# 130279 250481 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978541395552 | 40.860713935208594 | THEBRONX
# 130280 250480 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978305409506 | 40.86070184058383 | THEBRONX
# 130281 250480 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978305409506 | 40.86070184058383 | THEBRONX
# 130282 250474 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978012945587 | 40.86068981790809 | THEBRONX
# 130283 250474 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87978012945587 | 40.86068981790809 | THEBRONX
# 130284 250470 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87977664508841 | 40.86067788092349 | THEBRONX
# 130285 250470 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87977664508841 | 40.86067788092349 | THEBRONX
# 130286 250467 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797726036114 | 40.8606660458825 | THEBRONX
# 130287 250467 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797726036114 | 40.8606660458825 | THEBRONX
# 130288 250464 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87976801117705 | 40.86065432736601 | THEBRONX
# 130289 250464 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87976801117705 | 40.86065432736601 | THEBRONX
# 130290 250461 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87976287393872 | 40.86064273928476 | THEBRONX
# 130291 250461 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87976287393872 | 40.86064273928476 | THEBRONX
# 130292 250459 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87975719716292 | 40.860631297893946 | THEBRONX
# 130293 250459 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87975719716292 | 40.860631297893946 | THEBRONX
# 130294 250455 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87975098943079 | 40.860620016771804 | THEBRONX
# 130295 250455 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87975098943079 | 40.860620016771804 | THEBRONX
# 130296 250451 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87974425711661 | 40.86060890966181 | THEBRONX
# 130297 250451 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87974425711661 | 40.86060890966181 | THEBRONX
# 130298 250449 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87973701034393 | 40.860597991316496 | THEBRONX
# 130299 250449 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87973701034393 | 40.860597991316496 | THEBRONX
# 130300 250444 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87972925637048 | 40.860587274977654 | THEBRONX
# 130301 250444 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87972925637048 | 40.860587274977654 | THEBRONX
# 130302 250441 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87972100686494 | 40.86057677506435 | THEBRONX
# 130303 250441 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87972100686494 | 40.86057677506435 | THEBRONX
# 130304 250432 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971227085143 | 40.860566504150135 | THEBRONX
# 130305 250432 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.87971227085143 | 40.860566504150135 | THEBRONX
# 130306 250425 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797030595597 | 40.86055647531341 | THEBRONX
# 130307 250425 | MITSUBISHI WILD WETLAND TRL | MITSUBISHI WILD WETLAND TRL | -73.8797030595597 | 40.86055647531341 | THEBRONX
# 130308 73458 | BEACH AVE PEDESTRIAN OPAS | BEACH AVE PEDESTRIAN OPAS | -73.86492491409828 | 40.82493762940892 | THEBRONX
# 130309 73458 | BEACH AVE PEDESTRIAN OPAS | BEACH AVE PEDESTRIAN OPAS | -73.86492491409828 | 40.82493762940892 | THEBRONX
# 130310 73449 | BEACH AVE PEDESTRIAN OPAS | BEACH AVE PEDESTRIAN OPAS | -73.86461587126641 | 40.824978086484364 | THEBRONX
# 130311 278777 | PURDY ST | STARLING AVE | -73.85322274838713 | 40.83625644685662 | THEBRONX
# 130312 278777 | PURDY ST | STARLING AVE | -73.85322274838713 | 40.83625644685662 | THEBRONX
# 130313 278777 | PURDY ST | STARLING AVE | -73.85322274838713 | 40.83625644685662 | THEBRONX
# 130314 278777 | PURDY ST | STARLING AVE | -73.85322274838713 | 40.83625644685662 | THEBRONX
# 130315 161405 | ELDER AVE PEDESTRIAN OPAS | ELDER AVE PEDESTRIAN OPAS | -73.877850730917 | 40.8234996250359 | THEBRONX
# 130316 161405 | ELDER AVE PEDESTRIAN OPAS | ELDER AVE PEDESTRIAN OPAS | -73.877850730917 | 40.8234996250359 | THEBRONX
# 130317 150940 | E 165 ST | TIFFANY ST | -73.89487088534919 | 40.82393727215579 | THEBRONX
# 130318 150940 | E 165 ST | TIFFANY ST | -73.89487088534919 | 40.82393727215579 | THEBRONX
# 130319 150940 | E 165 ST | TIFFANY ST | -73.89487088534919 | 40.82393727215579 | THEBRONX
# 130320 150940 | E 165 ST | TIFFANY ST | -73.89487088534919 | 40.82393727215579 | THEBRONX
# 130321 29486 | 7 AVE | EDGE ST | -73.80866004722505 | 40.82289465445179 | THEBRONX
# 130322 29486 | 7 AVE | EDGE ST | -73.80866004722505 | 40.82289465445179 | THEBRONX
# 130323 29486 | 7 AVE | EDGE ST | -73.80866004722505 | 40.82289465445179 | THEBRONX
# 130324 29486 | 7 AVE | EDGE ST | -73.80866004722505 | 40.82289465445179 | THEBRONX
# 130325 100551 | BRUCKNER BLVD | BRUSH AVE | HUTCHINSON RIVER GREENWAY | -73.84118832754615 | 40.82856356968675 | THEBRONX
# 130326 100551 | BRUCKNER BLVD | BRUSH AVE | HUTCHINSON RIVER GREENWAY | -73.84118832754615 | 40.82856356968675 | THEBRONX
# 130327 100551 | BRUCKNER BLVD | BRUSH AVE | HUTCHINSON RIVER GREENWAY | -73.84118832754615 | 40.82856356968675 | THEBRONX
# 130328 100551 | BRUCKNER BLVD | BRUSH AVE | HUTCHINSON RIVER GREENWAY | -73.84118832754615 | 40.82856356968675 | THEBRONX
# 130329 100551 | BRUCKNER BLVD | BRUSH AVE | HUTCHINSON RIVER GREENWAY | -73.84118832754615 | 40.82856356968675 | THEBRONX
# 130330 157543 | EAST AVE | YANKEE MALL | -73.86034177868652 | 40.836375426280334 | THEBRONX
# 130331 157543 | EAST AVE | YANKEE MALL | -73.86034177868652 | 40.836375426280334 | THEBRONX
# 130332 157543 | EAST AVE | YANKEE MALL | -73.86034177868652 | 40.836375426280334 | THEBRONX
# 130333 121287 | CONNECTOR | GRAND CONC | -73.89191718327187 | 40.86930210907092 | THEBRONX
# 130334 121287 | CONNECTOR | GRAND CONC | -73.89191718327187 | 40.86930210907092 | THEBRONX
# 130335 121287 | CONNECTOR | GRAND CONC | -73.89191718327187 | 40.86930210907092 | THEBRONX
# 130336 187403 | GRAND CONC | GRAND CONC | -73.89174633546574 | 40.8695105475523 | THEBRONX
# 130337 187403 | GRAND CONC | GRAND CONC | -73.89174633546574 | 40.8695105475523 | THEBRONX
# 130338 187401 | GRAND CONC | GRAND CONC | -73.89157400109607 | 40.869684251835736 | THEBRONX
# 130339 187401 | GRAND CONC | GRAND CONC | -73.89157400109607 | 40.869684251835736 | THEBRONX
# 130340 187398 | GRAND CONC | GRAND CONC | -73.89138947035 | 40.8698509931797 | THEBRONX
# 130341 187398 | GRAND CONC | GRAND CONC | -73.89138947035 | 40.8698509931797 | THEBRONX

# %% [markdown]
# ### Select Orig and Dest Node

# %%
# destnames = ['BROADWAY','WASHINGTON PL','MANHATTAN']
#orignames = ['79 ST','LINDEN BLVD','QUEENS']
orignames = ['MITSUBISHI WILD WETLAND TRL','THEBRONX']
destnames = ['ARTHUR KILL RD','DOANE AVE','STATENISLAND']
nodenames1 = edgedatabase['nodename1'].values
nodenames2 = edgedatabase['nodename2'].values
origlist = []
destlist = []
for n in range(len(nodenames1)):
    count = 0
    for origname in orignames:
        if origname in nodenames1[n]: count = count + 1
    if (count > 2):
        index = edgedatabase.iloc[n].index1
        origlist.append(index)
    count = 0
    for origname in orignames:
        if origname in nodenames2[n]: count = count + 1
    if (count > 2): 
        index = edgedatabase.iloc[n].index2
        origlist.append(index)
for n in range(len(nodenames1)):
    count = 0
    for destname in destnames:
        if destname in nodenames1[n]: count = count + 1
    if (count > 2): 
        index = edgedatabase.iloc[n].index1
        destlist.append(index)
    count = 0
    for destname in destnames:
        if destname in nodenames2[n]: count = count + 1
    if (count > 2): 
        index = edgedatabase.iloc[n].index2
        destlist.append(index)
origlist = np.unique(origlist)
destlist = np.unique(destlist)
print(origlist)
print(destlist)
# Out:
# []
# [61177]

# %% [markdown]
# ### Run Dijkstra

# %%
source = origlist[0]
target = destlist[0]
route = []
path = nx.shortest_path(G, source=source, target=target)
for i in range(len(path)-1):
    orig = path[i]
    dest = path[i+1]
    weight = G[orig][dest]['weight']
    node1 = N[orig]
    node2 = N[dest]
    elements1 = node1.split(' | ')
    elements2 = node2.split(' | ')
    route.append((float(elements1[-3]),float(elements1[-2])))
route.append((float(elements1[-3]),float(elements1[-2])))
route = np.array(route)

# %% [markdown]
# ### Read outline

# %%
sf = shapefile.Reader('../data/shapefiles/nyc_outline/nyc_outline.shp')
streetsShapeRecs = sf.shapeRecords()

# %% [markdown]
# ### Draw

# %%
points = np.array(streetsShapeRecs[0].shape.points)
parts = streetsShapeRecs[0].shape.parts
parts.append(points.shape[0])
plt.style.use('dark_background')
plt.figure(figsize=(9,9))
for i in range(len(parts)-1):
    spos = parts[i]
    epos = parts[i+1]
    polygon = points[spos:epos,:]
    plt.plot(polygon[:,0],polygon[:,1],c='w',linewidth=1);
plt.plot(route[:,0],route[:,1],c='r',linewidth=1);

# %%
X = {}
X['O'] = O
X['N'] = N
X['edges'] = newedges
X['nodes'] = newnodes + connodes 
X['nodenames'] = newnodenames + connodenames
X['edgedatabase'] = edgedatabase
X['G'] = G
X['Nlist'] = Nlist
X['streets'] = streets
pickle.dump(X,open('../data/graphs/nyc.p',"wb"))
